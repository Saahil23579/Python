# %%
'''
                     Data Types and Structures Questions

1. What are data structures, and why are they important?
    Data structures are specialized formats for organizing, storing, and accessing collections of data.
    They provide efficient ways to manage information based on its characteristics and intended use.
    Well-chosen data structures can:
	      Simplify data manipulation (adding, removing, modifying elements)
	      Optimize searching and sorting operations
	      Conserve memory usage

2. Explain the difference between mutable and immutable data types with examples.
      Mutable : Can be changed after creation. E.g. Lists, dictionaries, sets.
      Immutable : Cannot be changed after creation.E.g. Strings, tuples, numbers.

3. What are the main differences between lists and tuples in Python?
    Differences between lists and tuples in Python
     Mutability:
       Lists:  Mutable, elements can be modified after creation (add, remove, change).
       Tuples: Immutable, elements cannot be modified after creation.
     Syntax:
       Lists:  Defined using square brackets [].
       Tuples: Defined using parentheses ().
     Performance:
       Lists:  Slightly slower due to their mutable nature.
       Tuples: Faster and more memory efficient, as they don't need the overhead for potential changes.
     Use Cases:
       Lists: Use when you need a collection of items that can be modified.
       Tuples: Use when you need a fixed collection of items that should not be changed (e.g., coordinates, database records).

4. Describe how dictionaries store data.
       Dictionaries in Python store data as key-value pairs using a structure called a hash table.
       This allows for highly efficient data retrieval, insertion, and deletion, with an average time complexity of O(1) for these operations.

5. Why might you use a set instead of a list in Python?
   Sets are preferred over list in Python in below case:
    1.Sets automatically enforce unique elements, meaning they do not allow duplicates.
    2.Sets allows faster operation than a list because sets are implemented as hash tables.
    3.Sets support mathematical set operations like union, intersection, difference, and symmetric difference.

6. What is a string in Python, and how is it different from a list?
      A string is a sequence of characters between single or double quotes.
      A list is a sequence of items, where each item could be anything (an integer, a float, a string, etc).

7. How do tuples ensure data integrity in Python?
      Tuples ensure data integrity in Python through their immutability. Once a tuple is created, its elements cannot be modified, added, or removed.
      This makes tuples a reliable way to store data that should remain constant throughout the program's execution.

8. What is a hash table, and how does it relate to dictionaries in Python?
    A hash table uses a hash function to map keys to specific indices in an array (called buckets).
    These indices determine where the values associated with the keys are stored.
    Python dictionaries are built on hash tables, providing constant-time complexity (O(1)) for basic operations like insertion, deletion, and lookup, in the average case.

9. Can lists contain different data types in Python?
     Yes.A list is a sequence of items, where each item could be anything (an integer, a float, a string, etc).

10. Explain why strings are immutable in Python.
      The immutability of Python string is very useful as it helps in hashing, performance optimization, safety, ease of use, etc.

11. What advantages do dictionaries offer over lists for certain tasks?
     Scenarios where dictionaries are preferred over lists:
      Storing user information: Using usernames as keys to access user details like email addresses and passwords.
      Mapping data: Associating one set of values with another, like translating words between languages.
      Caching data: Storing frequently accessed data with quick access using key

12. Describe a scenario where using a tuple would be preferable over a list.
      Scenarios where tuple are preferred over lists:
        Tuples are immutable, meaning their elements cannot be changed once created. This is useful for situations where it is required  to ensure data integrity and prevent accidental modifications.
        Tuples can be used as keys in dictionaries because they are hashable (due to their immutability), while lists cannot.
        Tuples can sometimes be slightly faster than lists for accessing elements because of their fixed structure.

13. How do sets handle duplicate values in Python?
      Sets in Python are inherently designed to handle duplicate values by automatically eliminating them.
      When you create a set or add elements to it, only unique values are retained.

14. How does the "in" keyword work differently for lists and dictionaries?
      When using the "in" keyword, it checks if a value exists within a list by comparing it to each element in the list.
      In a dictionary, "in" checks if a value exists as a key within the dictionary, meaning it only looks for the key and not the associated value

15. Can you modify the elements of a tuple? Explain why or why not.
      No. Tuple is immutable meaning we cannot modify element after creation.

16. What is a nested dictionary, and give an example of its use case?
        A nested dictionary is a data structure where a dictionary contains other dictionaries as its values, essentially creating a hierarchical organization of key-value pairs within a single dictionary
        E.g. people = {1: {'name': 'John', 'age': '27', 'sex': 'Male'}, 2: {'name': 'Marie', 'age': '22', 'sex': 'Female'}}

17. Describe the time complexity of accessing elements in a dictionary.
       Iterating over keys, values, or items in a dictionary has a time complexity of O(n) where n is the number of elements in the dictionary.

18. In what situations are lists preferred over dictionaries?
      Scenarios where lists are preferred over dictionaries:
         When order matters
         When it is required to store multiple instances of the same value:
         When it is required to access elements by position/index:
         When it is required to perform sequential operations:
         When the dataset is simple:


19. Why are dictionaries considered unordered, and how does that affect data retrieval?
      A dictionary is termed an unordered collection of objects because dictionaries do not maintain any inherent order of the items based on when they were added.
      Despite dictionaries being unordered, data retrieval by key remains efficient and direct because Python dictionaries are designed for fast key lookups using hash tables.
      This means you can still retrieve a value by its key in constant time  O(1)) on average, regardless of the dictionary's order.

20. Explain the difference between a list and a dictionary in terms of data retrieval.
      A list is an ordered collection of items, whereas a dictionary is an unordered data collection in a key: value pair.
      Elements from the list can be accessed using the index, while the elements of the dictionary can be accessed using keys.

'''

# %%
##1. Write a code to create a string with your name and print it.
name = "Welcome"
print(name)
# Out:
# Welcome

# %%
##2. Write a code to find the length of the string "Hello World".
var = "Hello World"
print(len(var))
# Out:
# 11

# %%
##3. Write a code to slice the first 3 characters from the string "Python Programming".
var = "Python Programming"
print(var[0:3])
# Out:
# Pyt

# %%
## 4. Write a code to convert the string "hello" to uppercase.
var = "hello"
print(var.upper())
# Out:
# HELLO

# %%
##5. Write a code to replace the word "apple" with "orange" in the string "I like apple".
var = "I like apple"
print(var.replace("apple","orange"))
# Out:
# I like orange

# %%
##6. Write a code to create a list with numbers 1 to 5 and print it.
list = list(range(1,6))
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
##7. Write a code to append the number 10 to the list [1, 2, 3, 4].
list = [1,2,3,4]
list.append(10)
print(list)
# Out:
# [1, 2, 3, 4, 10]

# %%
##8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].
list = [1,2,3,4,5]
list.remove(3)
print(list)
# Out:
# [1, 2, 4, 5]

# %%
##9. Write a code to access the second element in the list ['a', 'b', 'c', 'd'].
list = ['a', 'b', 'c', 'd']
print(list[1])
# Out:
# b

# %%
##10. Write a code to reverse the list [10, 20, 30, 40, 50].
list = [10, 20, 30, 40, 50]
list.reverse()
print(list)
# Out:
# [50, 40, 30, 20, 10]

# %%
##11. Write a code to create a tuple with the elements 10, 20, 30 and print it.
tuple = (10,20,30)
print(tuple)
# Out:
# (10, 20, 30)

# %%
##12. Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').
tuple = ('apple', 'banana', 'cherry')
print(tuple[0])
# Out:
# apple

# %%
##13. Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).
tuple = (1, 2, 3, 2, 4, 2)
print(tuple.count(2))
# Out:
# 3

# %%
##14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
tuple = ('dog', 'cat', 'rabbit')
print(tuple.index("cat"))
# Out:
# 1

# %%
##15. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').
tuple = ('apple', 'orange', 'banana')
print("banana" in tuple)
# Out:
# True

# %%
##16. Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.
set = {1,2,3,4,5}
print(set)
# Out:
# {1, 2, 3, 4, 5}

# %%
##17. Write a code to add the element 6 to the set {1, 2, 3, 4}.
set = {1,2,3,4}
set.add(6)
print(set)
# Out:
# {1, 2, 3, 4, 6}

# %%
##18. Write a code to create a tuple with the elements 10, 20, 30 and print it. //Repeated Qtn
##19. Write a code to access the first element of the tuple ('apple', 'banana', 'cherry'). //Repeated Qtn
##20. Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).  //Repeated Qtn
##21. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').  //Repeated Qtn
##22. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana') //Repeated Qtn
##23. Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.//Repeated Qtn
##24. Write a code to add the element 6 to the set {1, 2, 3, 4}.//Repeated Qtn
