# %%
'''
Python OOPS Questions
1. What is Object-Oriented Programming (OOP)?
   Object-oriented programming (OOP) is a programming model based on the concept of objects and classes which can help create software programmes, and includes basic principles like inheritance, encapsulation, polymorphism and abstraction.

2. What is a class in OOP?
   In Object-Oriented Programming (OOP), a class is a blueprint or template for creating objects. It defines the properties (attributes) and behaviors (methods) that the objects created from the class will have. A class acts as a design for objects, allowing you to model real-world entities in your program.

3. What is an object in OOP?
   In Object-Oriented Programming (OOP), an object is an instance of a class. It represents a real-world entity or concept and encapsulates data (attributes) and behavior (methods) defined by its class.

4. What is the difference between abstraction and encapsulation?
   Abstraction is the process of hiding the implementation details and showing only the essential features of an object to the user. It focuses on what an object does rather than how it does it.
   Encapsulation is the process of bundling data (attributes) and methods (functions) together into a single unit (class) and restricting direct access to some of the object's components. It focuses on how an object protects its data.

5. What are dunder methods in Python?
   Dunder methods (short for double underscore methods) are special methods in Python with names that begin and end with double underscores (__).
   They are also known as magic methods or special methods. These methods are predefined in Python to enable objects to interact with built-in functions, operators, and common language constructs in a clean and intuitive way.

6. Explain the concept of inheritance in OOP.
   Inheritance enables the creation of hierarchical relationships between classes, allowing for code reuse and extensibility.
   In inheritance, a class called the derived class inherits the attributes and methods of a base class. The derived class can extend the base class's functionality by adding new features or overriding existing ones

7. What is polymorphism in OOP?
   Polymorphism in Object-Oriented Programming (OOP) is the ability of a single function, method, or class to behave differently based on the context in which it is used.
   It enables a single interface to represent different types, enhancing flexibility and code reusability.

8. How is encapsulation achieved in Python?
   Encapsulation in Python is achieved by organizing data (attributes) and the methods that operate on it within a class and controlling access to this data.
   Python provides mechanisms like access modifiers and properties to implement encapsulation effectively.

9. What is a constructor in Python?
   In Python, a constructor is a special method used to initialize the attributes of an object when it is created. It is defined using the __init__ method within a class.
   The constructor is automatically called when an object of the class is instantiated.

10. What are class and static methods in Python?
    In Python, class methods and static methods are special types of methods within a class that differ in how they access the class and its instances.
    They are defined using decorators, and their behavior is distinct from regular instance methods.

    Class Method :A method that operates on the class itself rather than an instance of the class.
    Static Method: A method that does not depend on class or instance variables and works like a regular function, but it is logically related to the class.

11. What is method overloading in Python?
    Method overloading in Python refers to defining multiple methods with the same name but different arguments. It allows a method to perform different tasks based on the number or types of arguments passed.

    However, Python does not support method overloading in the traditional sense, as it only allows one method with a given name per class.
    In Python, if you define multiple methods with the same name in a class, the most recently defined method will overwrite the previous ones.

12. What is method overriding in OOP?
    Method overriding in Object-Oriented Programming (OOP) occurs when a subclass provides a specific implementation of a method that is already defined in its superclass. The method in the subclass must have the same name, return type, and parameters as the one in the superclass.
    This allows the subclass to provide a behavior specific to its own needs while still adhering to the structure defined by the superclas

13. What is a property decorator in Python?
    In Python, a property decorator (@property) is used to define a method in a class as a property. This allows us to access the method as if it were an attribute, rather than calling it like a method.

14. Why is polymorphism important in OOP?
    Polymorphism is a fundamental concept in Object-Oriented Programming (OOP) that enables a single interface to represent different types or classes.
    It allows objects of different classes to be treated as objects of a common superclass. This is achieved through method overriding, interfaces, or inheritance, and it plays a crucial role in making OOP flexible, extensible, and reusable

15. What is an abstract class in Python?
    An abstract class in Python is a class that cannot be instantiated on its own and is meant to be subclassed by other classes. It serves as a blueprint for other classe

16. What are the advantages of OOP?
    Advantages of OOP:
    1.Re-usability. It means reusing some facilities rather than building them again and again.
    2.Data Redundancy
    3.Code Maintenance
    4.Security
    5.Better productivity
    6.Easy troubleshooting
    7.Polymorphism Flexibility

17. What is the difference between a class variable and an instance variable?
    Class variable :
                    A class variable is a variable that is defined in a class and exists as a single copy, regardless of the number of class instances.
                    Class variables are suitable for data that needs to be consistent across a class hierarchy.
    Instance Variable :
                    An instance variable is a variable that is defined in a class and has a separate copy for each instance of the class.
                    Instance variables are ideal for storing data that is specific to an instance.

18. What is multiple inheritance in Python?
    Multiple inheritance in Python is a feature where a class can inherit from more than one parent class.
    This allows the derived class to access and use attributes and methods from all of its parent classes

19. Explain the purpose of "__str__' and '__repr__'' methods in Python.
     The __str__ method is meant to provide a human-readable or informal string representation of an object.
     It’s typically used to display information about the object in a friendly or user-facing format.

     The __repr__ method is meant to provide a developer-readable or formal string representation of an object.
     It is typically used to give detailed information that could be useful for debugging or reconstructing the object.


20. What is the significance of the 'super()' function in Python?
    The super() function in Python is significant because it allows you to call methods from a parent class (also known as a superclass) in a child class.
    This is especially useful in the context of inheritance, where a subclass inherits attributes and methods from a superclass.

21. What is the significance of the __del__ method in Python?
    The __del__ method in Python is a special method, also known as a destructor, that is called when an object is about to be destroyed by the garbage collector.
    Its primary purpose is to define cleanup actions that need to occur when an object is no longer needed.

22. What is the difference between @staticmethod and @classmethod in Python?
    In Python, @staticmethod and @classmethod are decorators used to define methods that do not operate in the traditional sense on an instance of a class.
    However, they serve different purposes and have distinct characteristics.A static method is a method that belongs to a class but does not depend on or modify the class or instance state.
    It is essentially a function that resides within a class for organizational purposes.A class method is a method that operates on the class itself rather than an instance. It receives the class (cls) as the first argument automatically.

23. How does polymorphism work in Python with inheritance?
    Polymorphism means "many forms." In object-oriented programming, it refers to the ability of different objects to respond to the same method or operation in a way specific to their class.
    Inheritance plays a central role in enabling polymorphism. A subclass can override methods of its superclass, and the overridden method is executed when called, even if the object is referenced by a variable of the superclass type.

24. What is method chaining in Python OOP?
    Method chaining in Python Object-Oriented Programming (OOP) is a technique where multiple methods are called on the same object in a single statement.
    This is achieved by designing methods to return the object itself (commonly done with the self keyword), allowing subsequent method calls to be "chained" together.

25. What is the purpose of the __call__ method in Python?
    The __call__ method in Python is a special (magic) method that allows an instance of a class to be called as if it were a function.
    This provides a way to make objects callable, enabling them to behave like functions while retaining their properties and methods as objects.

'''

# %%
                                        ###Practical Questions
##1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

class Animal:
    def speak(self):
        print("Generic animal sound")

class Dog(Animal):
    def speak(self):
        print(" Dog Bark!")

# Create instances of the classes
animal = Animal()
dog = Dog()

# Call the speak method for both instances
animal.speak()  # Output: Generic animal sound
dog.speak()  # Output: Bark!
# Out:
# Generic animal sound
#  Dog Bark!

# %%
#2 Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.
from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

def main():
    # Create a circle with radius 5
    circle = Circle(5)
    print(f"Area of the circle: {circle.area():.2f}")

    # Create a rectangle with width 4 and height 6
    rectangle = Rectangle(4, 6)
    print(f"Area of the rectangle: {rectangle.area()}")

if __name__ == "__main__":
    main()
# Out:
# Area of the circle: 78.54
# Area of the rectangle: 24

# %%
#3/4 Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, model):
        super().__init__(type)
        self.model = model

class ElectricCar(Car):
    def __init__(self, type, model, battery):
        super().__init__(type, model)
        self.battery = battery


my_electric_car = ElectricCar("electric", "Tesla Model S", "100kWh")
print(my_electric_car.type)
print(my_electric_car.model)
print(my_electric_car.battery)
# Out:
# electric
# Tesla Model S
# 100kWh

# %%
#5 Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance  # Private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ${amount:.2f}")
        else:
            print("Invalid deposit amount.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew: ${amount:.2f}")
        else:
            print("Insufficient funds or invalid withdrawal amount.")

    def check_balance(self):
        print(f"Current balance: ${self.__balance:.2f}")

# Create an account with an initial balance of $1000
account = BankAccount(1000)

# Perform some transactions
account.deposit(500)
account.withdraw(200)
account.check_balance()
# Out:
# Deposited: $500.00
# Withdrew: $200.00
# Current balance: $1300.00

# %%
#6 Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

class Instrument:
    def play(self):
        print("Playing a generic instrument sound")

class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar")

class Piano(Instrument):
    def play(self):
        print("Playing the piano keys")

# Create instances of the classes
instrument = Instrument()
guitar = Guitar()
piano = Piano()

# Call the play method for each instance
instrument.play()  # Output: Playing a generic instrument sound
guitar.play()  # Output: Strumming the guitar
piano.play()  # Output: Playing the piano keys
# Out:
# Playing a generic instrument sound
# Strumming the guitar
# Playing the piano keys

# %%
##7 Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract numbers() to subtract two numbers.
class MathOperations:
    @classmethod
    def add_numbers(cls, num1, num2):
        """Adds two numbers together."""
        return num1 + num2

    @staticmethod
    def subtract_numbers(num1, num2):
        """Subtracts two numbers."""
        return num1 - num2
if __name__ == "__main__":
  result_add =MathOperations.add_numbers(5, 3)  # Using class method
  result_subtract = MathOperations.subtract_numbers(10, 4)  # Using static method
  print(f"Addition result: {result_add}")
  print(f"Addition result: {result_subtract}")
# Out:
# Addition result: 8
# Addition result: 6

# %%
##8 Implement a class Person with a class method to count the total number of persons created.
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

if __name__ == "__main__":
    person1 = Person("Alice")
    person2 = Person("Bob")
    print(f"Total persons created: {Person.total_persons()}")
# Out:
# Total persons created: 2

# %%
##9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"  # Override __str__ for desired output

fraction = Fraction(3, 4)
print(f"Fraction: {fraction}")
# Out:
# Fraction: 3/4

# %%
##10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        """Overloads the + operator to add two Vector objects."""
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        """Returns a string representation of the Vector object."""
        return f"({self.x}, {self.y})"

# Create two Vector objects
v1 = Vector(2, 3)
v2 = Vector(4, 5)

# Add the two vectors using the overloaded + operator
v3 = v1 + v2

# Print the result
print(f"v1 + v2 = {v3}")
# Out:
# v1 + v2 = (6, 8)

# %%
#11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

person = Person("Alice", 30)
person.greet()
# Out:
# Hello, my name is Alice and I am 30 years old.

# %%
##12. Implement a class Student with attributes name and grades. Create a method average grade() to compute the average of the grades.

class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if self.grades:  # Check if grades list is not empty to avoid ZeroDivisionError
            return sum(self.grades) / len(self.grades)
        else:
            return 0  # Or you can handle this case differently (e.g., raise an exception)

Student = Student("Alice1", [30,40,50])
Student.average_grade()
print(f"{Student.name}'s average grade is: {Student.average_grade():.2f}")
# Out:
# Alice1's average grade is: 40.00

# %%
#13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
class Rectangle:
    def __init__(self, width=0, height=0):
        """Initializes the Rectangle object with optional width and height."""
        self.width = width
        self.height = height

    def set_dimensions(self, width, height):
        """Sets the dimensions of the rectangle."""
        self.width = width
        self.height = height

    def area(self):
        """Calculates and returns the area of the rectangle."""
        return self.width * self.height

rectangle = Rectangle(51, 39)
print(f"Area of the rectangle: {rectangle.area()}")
# Out:
# Area of the rectangle: 1989

# %%
#14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate.
##Create a derived class Manager that adds a bonus to the salary.

class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

Employee = Employee("Alice", 40, 15)
print(f"{Employee.name}'s salary: {Employee.calculate_salary()}")

Manager = Manager("Bob", 40, 15, 1000)
print(f"{Manager.name}'s salary: {Manager.calculate_salary()}")
# Out:
# Alice's salary: 600
# Bob's salary: 1600

# %%
##15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

product = Product("Bob", 40, 10)
print(f"{product.name}'s salary: {product.total_price()}")
# Out:
# Bob's salary: 400

# %%
##16. Create a class Animal with an abstract method sound().
##Create two derived classes Cow and Sheep that implement the sound() method.

from abc import ABC, abstractmethod

class Animal(ABC):  # Abstract base class
    @abstractmethod
    def sound(self):
        pass  # Abstract method (no implementation)

class Cow(Animal):
    def sound(self):
        print("Moo!")

class Sheep(Animal):
    def sound(self):
        print("Baa!")

# Create instances and call the sound method
cow = Cow()
cow.sound()

sheep = Sheep()
sheep.sound()
# Out:
# Moo!
# Baa!

# %%
##17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}\nAuthor: {self.author}\nYear Published: {self.year_published}"

book = Book("The Great Gatsby", "F. Scott Fitzgerald", 1925)
print(book.get_book_info())
# Out:
# Title: The Great Gatsby
# Author: F. Scott Fitzgerald
# Year Published: 1925

# %%
##18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

House = House("123 Main St", 250000)
print(f"Address: {House.address}\nPrice: ${House.price}")

Mansion = Mansion("456 Oak St", 350000, 3)
print(f"Address: {Mansion.address}\nPrice: ${Mansion.price}\nNumber of Rooms: {Mansion.number_of_rooms}")
# Out:
# Address: 123 Main St
# Price: $250000
# Address: 456 Oak St
# Price: $350000
# Number of Rooms: 3
